# %%
import requests
import json

def province():
    prov_list = intext_file[num]
    province = prov_list['Province']
    print(province)

def confirmed():
    index = intext_file[num]
    confirmed = index['Confirmed']
    print(confirmed)
    
def deaths():
    deaths_list = intext_file[num]
    deaths = deaths_list['Deaths']
    print(deaths)
    
def recovered():
    recovered_list = intext_file[num]
    recovered = recovered_list['Recovered']
    print(recovered)
    
def active():
    active_list = intext_file[num]
    active = active_list['Active']
    print(active)
    
country = "russia"
intext = requests.get(f"https://api.covid19api.com/live/country/{country}")
intext_file = intext.json()

num = 0
for i in intext_file:
    province()
    confirmed()
    deaths()
    recovered()
    active()
    num+=1
# Out:
# Udmurt Republic
# 35147
# 1033
# 31979
# 2135
# Amur Oblast
# 23608
# 302
# 22879
# 427
# Adygea Republic
# 14916
# 234
# 14367
# 315
# North Ossetia - Alania Republic
# 17220
# 227
# 16532
# 461
# Astrakhan Oblast
# 35367
# 834
# 34007
# 526
# Orenburg Oblast
# 46236
# 1078
# 42410
# 2748
# Kaluga Oblast
# 36950
# 365
# 35297
# 1288
# Chukotka Autonomous Okrug
# 797
# 8
# 746
# 43
# Kamchatka Krai
# 15040
# 238
# 14102
# 700
# Moscow Oblast
# 298855
# 6400
# 244419
# 48036
# Kursk Oblast
# 40088
# 908
# 38402
# 778
# Omsk Oblast
# 49581
# 1482
# 47042
# 1057
# Ingushetia Republic
# 16049
# 190
# 15639
# 220
# Tyumen Oblast
# 38328
# 644
# 36717
# 967
# Moscow
# 1315841
# 21778
# 1131022
# 163041
# Irkutsk Oblast
# 72800
# 2636
# 68846
# 1318
# Smolensk Oblast
# 33290
# 1090
# 30952
# 1248
# Kostroma Oblast
# 22639
# 505
# 19597
# 2537
# Tatarstan Republic
# 22215
# 529
# 19880
# 1806
# Magadan Oblast
# 8619
# 115
# 8374
# 130
# Tver Oblast
# 44670
# 1162
# 40950
# 2558
# ...
